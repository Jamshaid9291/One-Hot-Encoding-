# %% [markdown]
# <a href="https://colab.research.google.com/github/Jamshaid9291/One-Hot-Encoding-/blob/main/One_Hot_Encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/cars.csv")

# %%
df.sample(15)
# Out:
#           brand  km_driven    fuel                 owner  selling_price
# 7180      Honda      50000  Diesel           First Owner         440000
# 120      Nissan      70000  Diesel           Third Owner         400000
# 1047    Renault      21000  Petrol           First Owner         290000
# 184       Honda     120000  Petrol          Second Owner         100000
# 898     Hyundai     100000  Diesel  Fourth & Above Owner         270000
# 264     Hyundai       2000  Diesel          Second Owner         550000
# 1726      Skoda      11000  Petrol           First Owner         645000
# 5723   Mahindra     112000  Diesel           First Owner         450000
# 1298       Tata      96443  Diesel          Second Owner         535000
# 5339   Mahindra      50000  Diesel           First Owner         500000
# 2095  Chevrolet     120000  Diesel          Second Owner         225000
# 3944       Tata     195000  Diesel          Second Owner         140000
# ...

# %%
df['brand'].value_counts()
# Out:
# brand
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Force               6
# Land                6
# Isuzu               5
# Kia                 4
# Ambassador          4
# Daewoo              3
# MG                  3
# Ashok               1
# Opel                1
# Peugeot             1
# Name: count, dtype: int64

# %%
df['brand'].nunique()
# Out:
# 32

# %%
df['fuel'].value_counts()
# Out:
# fuel
# Diesel    4402
# Petrol    3631
# CNG         57
# LPG         38
# Name: count, dtype: int64

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             5289
# Second Owner            2105
# Third Owner              555
# Fourth & Above Owner     174
# Test Drive Car             5
# Name: count, dtype: int64

# %% [markdown]
# **Using Sklearn**

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,0:4],df.iloc[:,-1],test_size=0.2,random_state=2)

# %%
X_train.head()
# Out:
#          brand  km_driven    fuel         owner
# 5571   Hyundai      35000  Diesel   First Owner
# 2038      Jeep      60000  Diesel   First Owner
# 2957   Hyundai      25000  Petrol   First Owner
# 7618  Mahindra     130000  Diesel  Second Owner
# 6684   Hyundai     155000  Diesel   First Owner

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder(drop='first')

# %%
X_train_new = ohe.fit_transform(X_train[['fuel','owner']]).toarray()

# %%
X_test_new = ohe.transform(X_test[['fuel','owner']]).toarray()

# %%
X_train_new.shape
# Out:
# (6502, 7)

# %%
import numpy as np
np.hstack((X_train[['brand','km_driven']].values,X_train_new))
# Out:
# array([['Hyundai', 35000, 1.0, ..., 0.0, 0.0, 0.0],
#        ['Jeep', 60000, 1.0, ..., 0.0, 0.0, 0.0],
#        ['Hyundai', 25000, 0.0, ..., 0.0, 0.0, 0.0],
#        ...,
#        ['Tata', 15000, 0.0, ..., 0.0, 0.0, 0.0],
#        ['Maruti', 32500, 1.0, ..., 1.0, 0.0, 0.0],
#        ['Isuzu', 121000, 1.0, ..., 0.0, 0.0, 0.0]], dtype=object)

# %% [markdown]
# **One Hot encoding with Top Categories**

# %%
counts = df['brand'].value_counts()

# %%
df['brand'].nunique()
threshold = 100

# %%
repl = counts[counts <= threshold].index

# %%
pd.get_dummies(df['brand'].replace(repl, 'uncommon')).sample(5)
# Out:
#         BMW  Chevrolet   Ford  Honda  Hyundai  Mahindra  Maruti  Renault  \
# 221   False      False  False  False    False     False   False     True
# 7621  False      False  False  False    False     False   False    False
# 2732  False      False  False  False     True     False   False    False
# 1413  False      False  False  False    False     False    True    False
# 5663  False      False  False  False     True     False   False    False
#
#       Skoda   Tata  Toyota  Volkswagen  uncommon
# 221   False  False   False       False     False
# 7621  False   True   False       False     False
# 2732  False  False   False       False     False
# 1413  False  False   False       False     False
# 5663  False  False   False       False     False
